# %% [markdown]
# Json Data Processing Using Pandas

# %%
import pandas as pd

# %%
df = pd.read_json('wk.json', typ='series')

# %%
print("series\n", df)
# Out:
# series
#  result    [{'scriptId': '24', 'url': 'https://www.wikipe...
# dtype: object

# %%
df.head(10)
# Out:
# result    [{'scriptId': '24', 'url': 'https://www.wikipe...
# dtype: object

# %%
len(df.result)
# Out:
# 4

# %%
df
# Out:
# result    [{'scriptId': '24', 'url': 'https://www.wikipe...
# dtype: object

# %%
df.result
# Out:
# [{'functions': [{'functionName': '',
#     'isBlockCoverage': True,
#     'ranges': [{'count': 1, 'endOffset': 123, 'startOffset': 0}]}],
#   'scriptId': '24',
#   'url': 'https://www.wikipedia.org/'},
#  {'functions': [{'functionName': '',
#     'isBlockCoverage': True,
#     'ranges': [{'count': 1, 'endOffset': 926, 'startOffset': 0}]},
#    {'functionName': 'makeVisible',
#     'isBlockCoverage': True,
#     'ranges': [{'count': 2, 'endOffset': 861, 'startOffset': 678},
#      {'count': 1, 'endOffset': 851, 'startOffset': 730}]}],
#   'scriptId': '25',
#   'url': 'https://www.wikipedia.org/'},
#  {'functions': [{'functionName': '',
#     'isBlockCoverage': True,
#     'ranges': [{'count': 1, 'endOffset': 25310, 'startOffset': 0}]},
#    {'functionName': 'addEvent',
#     'isBlockCoverage': True,
#     'ranges': [{'count': 16, 'endOffset': 146, 'startOffset': 0},
#      {'count': 0, 'endOffset': 144, 'startOffset': 75}]},
#    {'functionName': 'removeEvent',
# ...

# %%
df.result[1]['url']
# Out:
# 'https://www.wikipedia.org/'

# %%
df.result['url']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-f29609e436b2> in <module>()
# ----> 1 df.result['url']
#
# TypeError: list indices must be integers or slices, not str

# %%
type(df.result[1]['functions'])
# Out:
# list

# %%
len(df.result[2]['functions'])
# Out:
# 124

# %%
df.result[2]['functions'][1]
# Out:
# {'functionName': 'addEvent',
#  'isBlockCoverage': True,
#  'ranges': [{'count': 16, 'endOffset': 146, 'startOffset': 0},
#   {'count': 0, 'endOffset': 144, 'startOffset': 75}]}

# %%
len(df.result)
# Out:
# 4

# %%
for i in range(len(df.result)):
    print(df.result[i]['url'])
# Out:
# https://www.wikipedia.org/
# https://www.wikipedia.org/
# https://www.wikipedia.org/portal/wikipedia.org/assets/js/index-47f5f07682.js
# https://www.wikipedia.org/portal/wikipedia.org/assets/js/gt-ie9-011f8dbfa9.js

# %%
for i in range(len(df.result)):
    for j in range(len(df.result[i]['functions'])):
        print(df.result[i]['functions'][j])
# Out:
# {'functionName': '', 'ranges': [{'startOffset': 0, 'endOffset': 123, 'count': 1}], 'isBlockCoverage': True}
# {'functionName': '', 'ranges': [{'startOffset': 0, 'endOffset': 926, 'count': 1}], 'isBlockCoverage': True}
# {'functionName': 'makeVisible', 'ranges': [{'startOffset': 678, 'endOffset': 861, 'count': 2}, {'startOffset': 730, 'endOffset': 851, 'count': 1}], 'isBlockCoverage': True}
# {'functionName': '', 'ranges': [{'startOffset': 0, 'endOffset': 25310, 'count': 1}], 'isBlockCoverage': True}
# {'functionName': 'addEvent', 'ranges': [{'startOffset': 0, 'endOffset': 146, 'count': 16}, {'startOffset': 75, 'endOffset': 144, 'count': 0}], 'isBlockCoverage': True}
# {'functionName': 'removeEvent', 'ranges': [{'startOffset': 146, 'endOffset': 267, 'count': 10}, {'startOffset': 227, 'endOffset': 265, 'count': 0}], 'isBlockCoverage': True}
# ...

# %%
frame = df.result

# %%
frame
# Out:
# [{'functions': [{'functionName': '',
#     'isBlockCoverage': True,
#     'ranges': [{'count': 1, 'endOffset': 123, 'startOffset': 0}]}],
#   'scriptId': '24',
#   'url': 'https://www.wikipedia.org/'},
#  {'functions': [{'functionName': '',
#     'isBlockCoverage': True,
#     'ranges': [{'count': 1, 'endOffset': 926, 'startOffset': 0}]},
#    {'functionName': 'makeVisible',
#     'isBlockCoverage': True,
#     'ranges': [{'count': 2, 'endOffset': 861, 'startOffset': 678},
#      {'count': 1, 'endOffset': 851, 'startOffset': 730}]}],
#   'scriptId': '25',
#   'url': 'https://www.wikipedia.org/'},
#  {'functions': [{'functionName': '',
#     'isBlockCoverage': True,
#     'ranges': [{'count': 1, 'endOffset': 25310, 'startOffset': 0}]},
#    {'functionName': 'addEvent',
#     'isBlockCoverage': True,
#     'ranges': [{'count': 16, 'endOffset': 146, 'startOffset': 0},
#      {'count': 0, 'endOffset': 144, 'startOffset': 75}]},
#    {'functionName': 'removeEvent',
# ...

# %%
dtf = pd.DataFrame(frame)

# %%
dtf
# Out:
#                                            functions scriptId  \
# 0  [{'functionName': '', 'ranges': [{'startOffset...       24
# 1  [{'functionName': '', 'ranges': [{'startOffset...       25
# 2  [{'functionName': '', 'ranges': [{'startOffset...       26
# 3  [{'functionName': '', 'ranges': [{'startOffset...       27
#
#                                                  url
# 0                         https://www.wikipedia.org/
# 1                         https://www.wikipedia.org/
# 2  https://www.wikipedia.org/portal/wikipedia.org...
# 3  https://www.wikipedia.org/portal/wikipedia.org...

# %%
for i in range(len(df.result)):
    for j in range(len(df.result[i]['functions'])):
        print(df.result[i]['functions'][j]['ranges'])
# Out:
# [{'startOffset': 0, 'endOffset': 123, 'count': 1}]
# [{'startOffset': 0, 'endOffset': 926, 'count': 1}]
# [{'startOffset': 678, 'endOffset': 861, 'count': 2}, {'startOffset': 730, 'endOffset': 851, 'count': 1}]
# [{'startOffset': 0, 'endOffset': 25310, 'count': 1}]
# [{'startOffset': 0, 'endOffset': 146, 'count': 16}, {'startOffset': 75, 'endOffset': 144, 'count': 0}]
# [{'startOffset': 146, 'endOffset': 267, 'count': 10}, {'startOffset': 227, 'endOffset': 265, 'count': 0}]
# [{'startOffset': 267, 'endOffset': 505, 'count': 5}, {'startOffset': 433, 'endOffset': 436, 'count': 0}]
# [{'startOffset': 297, 'endOffset': 399, 'count': 5}]
# [{'startOffset': 386, 'endOffset': 398, 'count': 0}]
# [{'startOffset': 505, 'endOffset': 607, 'count': 8}, {'startOffset': 573, 'endOffset': 577, 'count': 0}, {'startOffset': 578, 'endOffset': 582, 'count': 5}, {'startOffset': 598, 'endOffset': 606, 'count': 5}]
# ...

# %%
source_data = []
for i in range(len(df.result)):
    for j in range(len(df.result[i]['functions'])):
        source_data.append(df.result[i]['functions'][j]['ranges'])

# %%
source_data
# Out:
# [[{'count': 1, 'endOffset': 123, 'startOffset': 0}],
#  [{'count': 1, 'endOffset': 926, 'startOffset': 0}],
#  [{'count': 2, 'endOffset': 861, 'startOffset': 678},
#   {'count': 1, 'endOffset': 851, 'startOffset': 730}],
#  [{'count': 1, 'endOffset': 25310, 'startOffset': 0}],
#  [{'count': 16, 'endOffset': 146, 'startOffset': 0},
#   {'count': 0, 'endOffset': 144, 'startOffset': 75}],
#  [{'count': 10, 'endOffset': 267, 'startOffset': 146},
#   {'count': 0, 'endOffset': 265, 'startOffset': 227}],
#  [{'count': 5, 'endOffset': 505, 'startOffset': 267},
#   {'count': 0, 'endOffset': 436, 'startOffset': 433}],
#  [{'count': 5, 'endOffset': 399, 'startOffset': 297}],
#  [{'count': 0, 'endOffset': 398, 'startOffset': 386}],
#  [{'count': 8, 'endOffset': 607, 'startOffset': 505},
#   {'count': 0, 'endOffset': 577, 'startOffset': 573},
#   {'count': 5, 'endOffset': 582, 'startOffset': 578},
#   {'count': 5, 'endOffset': 606, 'startOffset': 598}],
# ...

# %%
source_frame = pd.DataFrame(source_data)

# %%
source_frame.head()
# Out:
#                                                    0  \
# 0   {'startOffset': 0, 'endOffset': 123, 'count': 1}
# 1   {'startOffset': 0, 'endOffset': 926, 'count': 1}
# 2  {'startOffset': 678, 'endOffset': 861, 'count'...
# 3  {'startOffset': 0, 'endOffset': 25310, 'count'...
# 4  {'startOffset': 0, 'endOffset': 146, 'count': 16}
#
#                                                    1     2     3     4
# 0                                               None  None  None  None
# 1                                               None  None  None  None
# 2  {'startOffset': 730, 'endOffset': 851, 'count'...  None  None  None
# 3                                               None  None  None  None
# 4  {'startOffset': 75, 'endOffset': 144, 'count': 0}  None  None  None

# %%
len(source_data)
# Out:
# 134

# %%
import json

# %%
dir(json)
# Out:
# ['JSONDecodeError',
#  'JSONDecoder',
#  'JSONEncoder',
#  '__all__',
#  '__author__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_default_decoder',
#  '_default_encoder',
#  'codecs',
#  'decoder',
#  'detect_encoding',
#  'dump',
#  'dumps',
#  'encoder',
#  'load',
#  'loads',
#  'scanner']

# %%
dh = None
with open("wk.json") as f:
    dh = json.loads(f.read())
print(dh)
# Out:
# {'result': [{'scriptId': '24', 'url': 'https://www.wikipedia.org/', 'functions': [{'functionName': '', 'ranges': [{'startOffset': 0, 'endOffset': 123, 'count': 1}], 'isBlockCoverage': True}]}, {'scriptId': '25', 'url': 'https://www.wikipedia.org/', 'functions': [{'functionName': '', 'ranges': [{'startOffset': 0, 'endOffset': 926, 'count': 1}], 'isBlockCoverage': True}, {'functionName': 'makeVisible', 'ranges': [{'startOffset': 678, 'endOffset': 861, 'count': 2}, {'startOffset': 730, 'endOffset': 851, 'count': 1}], 'isBlockCoverage': True}]}, {'scriptId': '26', 'url': 'https://www.wikipedia.org/portal/wikipedia.org/assets/js/index-47f5f07682.js', 'functions': [{'functionName': '', 'ranges': [{'startOffset': 0, 'endOffset': 25310, 'count': 1}], 'isBlockCoverage': True}, {'functionName': 'addEvent', 'ranges': [{'startOffset': 0, 'endOffset': 146, 'count': 16}, {'startOffset': 75, 'endOffset': 144, 'count': 0}], 'isBlockCoverage': True}, {'functionName': 'removeEvent', 'ranges': [{'start
# ...

# %%
result = dh['result']

# %%
import csv

with open('names.csv', 'w', newline='') as csvfile:
    fieldnames = ['first_name', 'last_name']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    writer.writerow({'first_name': 'Baked', 'last_name': 'Beans'})
    writer.writerow({'first_name': 'Lovely', 'last_name': 'Spam'})
    writer.writerow({'first_name': 'Wonderful', 'last_name': 'Spam'})
# Out:
# [{'functions': [{'functionName': '',
#     'isBlockCoverage': True,
#     'ranges': [{'count': 1, 'endOffset': 123, 'startOffset': 0}]}],
#   'scriptId': '24',
#   'url': 'https://www.wikipedia.org/'},
#  {'functions': [{'functionName': '',
#     'isBlockCoverage': True,
#     'ranges': [{'count': 1, 'endOffset': 926, 'startOffset': 0}]},
#    {'functionName': 'makeVisible',
#     'isBlockCoverage': True,
#     'ranges': [{'count': 2, 'endOffset': 861, 'startOffset': 678},
#      {'count': 1, 'endOffset': 851, 'startOffset': 730}]}],
#   'scriptId': '25',
#   'url': 'https://www.wikipedia.org/'},
#  {'functions': [{'functionName': '',
#     'isBlockCoverage': True,
#     'ranges': [{'count': 1, 'endOffset': 25310, 'startOffset': 0}]},
#    {'functionName': 'addEvent',
#     'isBlockCoverage': True,
#     'ranges': [{'count': 16, 'endOffset': 146, 'startOffset': 0},
#      {'count': 0, 'endOffset': 144, 'startOffset': 75}]},
#    {'functionName': 'removeEvent',
# ...

# %%
import csv
csvfile = open('chutiya.csv', 'w', newline='')
fieldnames = ['startOffset', 'endOffset', 'count']
writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

for r in result:
    for fn in r['functions']:
        for rang in fn['ranges']:
            writer.writerow(rang)

# %%
index_col=['startOffset', 'endOffset', 'count']
source_frame = pd.read_csv('chutiya.csv',names=index_col, header=None)

# %%
source_frame
# Out:
#      startOffset  endOffset  count
# 0              0        123      1
# 1              0        926      1
# 2            678        861      2
# 3            730        851      1
# 4              0      25310      1
# 5              0        146     16
# 6             75        144      0
# 7            146        267     10
# 8            227        265      0
# 9            267        505      5
# 10           433        436      0
# 11           297        399      5
# 12           386        398      0
# 13           505        607      8
# 14           573        577      0
# 15           578        582      5
# 16           598        606      5
# 17           607        853      2
# 18           702        852      0
# 19           853       3184      1
# 20           879        942      1
# 21           919        933      0
# 22           942       1039      1
# 23           992       1030     10
# 24          1039       1186      1
# 25          1160       1185      0
# ...
